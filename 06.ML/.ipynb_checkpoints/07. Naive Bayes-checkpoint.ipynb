# %% [markdown]
# # 붓꽃 분류
# - Naive Bayes Classifier
#   - 텍스트 데이터처럼 희소한 고차원인 경우 높은 정확도와 속도를 제공
#   - 적용분야: 스팸 메일 분류, 문서(주제) 분류, 컴퓨터 네트워크 침입자 분류 등

# %% [markdown]
# ## 패키지 로딩

# %%
from sklearn.datasets import load_iris
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# ## 데이터 로딩 및 분할

# %%
x, y = load_iris(return_X_y=True)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=10, stratify=y)

# %% [markdown]
# ## 모델 생성

# %%
model = GaussianNB()  # 설명변수가 연속형인 경우 사용하는 나이브 베이즈
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ## 모델 평가

# %%
y_hat = model.predict(x_test)
con_mat = confusion_matrix(y_test, y_hat)
print(con_mat)
# Out:
# [[15  0  0]
#  [ 0 15  0]
#  [ 0  0 15]]

# %% [markdown]
# # [실습] 독버섯 분류
# - 설명변수가 범주형 자료
# - 종속변수: type

# %%
# 데이터 불러오기
import pandas as pd
import numpy as np

df = pd.read_csv('./dataset/mushrooms.csv')

print(df.shape)
display(df.head(10))
# Out:
# (8124, 23)
#         type cap_shape cap_surface cap_color bruises  ... ring_number   ring_type spore_print_color population  habitat
# 0  poisonous    convex      smooth     brown     yes  ...         one     pendant             black  scattered    urban
# 1     edible    convex      smooth    yellow     yes  ...         one     pendant             brown   numerous  grasses
# 2     edible      bell      smooth     white     yes  ...         one     pendant             brown   numerous  meadows
# 3  poisonous    convex       scaly     white     yes  ...         one     pendant             black  scattered    urban
# 4     edible    convex      smooth      gray      no  ...         one  evanescent             brown   abundant  grasses
# 5     edible    convex       scaly    yellow     yes  ...         one     pendant             black   numerous  grasses
# 6     edible      bell      smooth     white     yes  ...         one     pendant             black   numerous  meadows
# 7     edible      bell       scaly     white     yes  ...         one     pendant             brown  scattered  meadows
# 8  poisonous    convex       scaly     white     yes  ...         one     pendant             black    several  grasses
# 9     edible      bell      smooth    yellow     yes  ...         one     pendant             black  scattered  meadows
#
# [10 rows x 23 columns]

# %%
# 인코딩
df_encoding = pd.get_dummies(df, columns=df.columns[1:])
# 종속변수는 원핫인코딩x, 종속변수는 하나의 컬럼만 있어야함
df_encoding
# Out:
#            type  cap_shape_bell  cap_shape_conical  ...  habitat_urban  habitat_waste  habitat_woods
# 0     poisonous           False              False  ...           True          False          False
# 1        edible           False              False  ...          False          False          False
# 2        edible            True              False  ...          False          False          False
# 3     poisonous           False              False  ...           True          False          False
# 4        edible           False              False  ...          False          False          False
# ...         ...             ...                ...  ...            ...            ...            ...
# 8119     edible           False              False  ...          False          False          False
# 8120     edible           False              False  ...          False          False          False
# 8121     edible           False              False  ...          False          False          False
# 8122  poisonous           False              False  ...          False          False          False
# 8123     edible           False              False  ...          False          False          False
#
# [8124 rows x 118 columns]

# %%
from sklearn.preprocessing import LabelEncoder

encoded = LabelEncoder().fit_transform(df_encoding['type'])
df_encoding['type'] = encoded
df_encoding
# Out:
#       type  cap_shape_bell  cap_shape_conical  ...  habitat_urban  habitat_waste  habitat_woods
# 0        1           False              False  ...           True          False          False
# 1        0           False              False  ...          False          False          False
# 2        0            True              False  ...          False          False          False
# 3        1           False              False  ...           True          False          False
# 4        0           False              False  ...          False          False          False
# ...    ...             ...                ...  ...            ...            ...            ...
# 8119     0           False              False  ...          False          False          False
# 8120     0           False              False  ...          False          False          False
# 8121     0           False              False  ...          False          False          False
# 8122     1           False              False  ...          False          False          False
# 8123     0           False              False  ...          False          False          False
#
# [8124 rows x 118 columns]

# %%
encoder = LabelEncoder()
for column in df.columns:
    df[column] = encoder.fit_transform(df[column])
df
# Out:
#       type  cap_shape  cap_surface  cap_color  bruises  ...  ring_number  ring_type  spore_print_color  population  habitat
# 0        1          2            3          0        1  ...            1          4                  0           3        4
# 1        0          2            3          9        1  ...            1          4                  1           2        0
# 2        0          0            3          8        1  ...            1          4                  1           2        2
# 3        1          2            2          8        1  ...            1          4                  0           3        4
# 4        0          2            3          3        0  ...            1          0                  1           0        0
# ...    ...        ...          ...        ...      ...  ...          ...        ...                ...         ...      ...
# 8119     0          4            3          0        0  ...            1          4                  2           1        1
# 8120     0          2            3          0        0  ...            1          4                  2           4        1
# 8121     0          3            3          0        0  ...            1          4                  2           1        1
# 8122     1          4            2          0        0  ...            1          0                  7           4        1
# 8123     0          2            3          0        0  ...            1          4                  5           1        1
#
# [8124 rows x 23 columns]

# %%
# 종속변수/독립변수 분리
x = df_encoding.drop('type', axis=1)
y = df['type']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y)

# %%
# 모델 생성
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
# 평가
y_hat = model.predict(x_test)

matrix = confusion_matrix(y_test, y_hat)
print(matrix)
print(f'정확도: {accuracy_score(y_test, y_hat):.3f}')
# Out:
# [[1258    5]
#  [ 125 1050]]
# 정확도: 0.947

# %%
from sklearn.metrics import roc_auc_score

pred_proba_positive = model.predict_proba(x_test)[:,1]
print(f'AUC: {roc_auc_score(y_test, pred_proba_positive)}')
# Out:
# AUC: 0.9978443759370631

# %% [markdown]
# # [답안]

# %% [markdown]
# ## 패키지로딩

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, roc_auc_score, roc_curve
import pandas as pd
import numpy as np

# %% [markdown]
# ## 데이터 로딩 및 확인

# %%
df = pd.read_csv('./dataset/mushrooms.csv')
print(df.shape)
display(df.head())
# Out:
# (8124, 23)
#         type cap_shape cap_surface cap_color bruises  ... ring_number   ring_type spore_print_color population  habitat
# 0  poisonous    convex      smooth     brown     yes  ...         one     pendant             black  scattered    urban
# 1     edible    convex      smooth    yellow     yes  ...         one     pendant             brown   numerous  grasses
# 2     edible      bell      smooth     white     yes  ...         one     pendant             brown   numerous  meadows
# 3  poisonous    convex       scaly     white     yes  ...         one     pendant             black  scattered    urban
# 4     edible    convex      smooth      gray      no  ...         one  evanescent             brown   abundant  grasses
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   type                      8124 non-null   object
#  1   cap_shape                 8124 non-null   object
#  2   cap_surface               8124 non-null   object
#  3   cap_color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill_attachment           8124 non-null   object
#  7   gill_spacing              8124 non-null   object
#  8   gill_size                 8124 non-null   object
#  9   gill_color                8124 non-null   object
#  10  stalk_shape               8124 non-null   object
#  11  stalk_root                8124 non-null   object
#  12  stalk_surface_above_ring  8124 non-null   object
#  13  stalk_surface_below_ring  8124 non-null   object
#  14  stalk_color_above_ring    8124 non-null   object
#  15  stalk_color_below_ring    8124 non-null   object
#  16  veil_type                 8124 non-null   object
#  17  veil_color                8124 non-null   object
#  18  ring_number               8124 non-null   object
#  19  ring_type                 8124 non-null   object
#  20  spore_print_color         8124 non-null   object
#  21  population                8124 non-null   object
#  22  habitat                   8124 non-null   object
# dtypes: object(23)
# memory usage: 1.4+ MB

# %% [markdown]
# ## 데이터 인코딩 및 분리

# %% [markdown]
# ### 라벨 인코딩

# %%
x = df.drop('type', axis=1)
y = df['type']

# %% [markdown]
# - scikit-learn LabelEncoder를 이용한 label encoding

# %%
from sklearn.preprocessing import LabelEncoder

x = x.apply(lambda col:LabelEncoder().fit_transform(col))
# x의 컬럼값을 lambda의 컬럼값으로 가져와 라벨인코딩 실행
x.head()
# Out:
#    cap_shape  cap_surface  cap_color  bruises  odor  ...  ring_number  ring_type  spore_print_color  population  habitat
# 0          2            3          0        1     7  ...            1          4                  0           3        4
# 1          2            3          9        1     0  ...            1          4                  1           2        0
# 2          0            3          8        1     1  ...            1          4                  1           2        2
# 3          2            2          8        1     7  ...            1          4                  0           3        4
# 4          2            3          3        0     6  ...            1          0                  1           0        0
#
# [5 rows x 22 columns]

# %% [markdown]
# - pandas map을 이용한 label encoding

# %%
def labeling(col):
    map_data = { v:i for i,v in enumerate(np.sort(col.unique()))}  # 각 컬럼의 고유값을 가져와 정렬 후 enumerate 각 인덱스와 값가져오기
    return map_data

x = x.apply(lambda col:col.map(labeling(col)))
# apply로 각 컬럼에 적용
# 각 컬럼값을 lambda의 매개변수인 col에 가져와 map함수를 통해 맵핑된 딕셔너리 객체를 이용해 라벨링

# %%
x.head()
# Out:
#    cap_shape  cap_surface  cap_color  bruises  odor  ...  ring_number  ring_type  spore_print_color  population  habitat
# 0          2            3          0        1     7  ...            1          4                  0           3        4
# 1          2            3          9        1     0  ...            1          4                  1           2        0
# 2          0            3          8        1     1  ...            1          4                  1           2        2
# 3          2            2          8        1     7  ...            1          4                  0           3        4
# 4          2            3          3        0     6  ...            1          0                  1           0        0
#
# [5 rows x 22 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=10, stratify=y)

print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (6499, 22) (1625, 22) (6499,) (1625,)

# %% [markdown]
# ### 원-핫 인코딩

# %%
x = df.drop('type', axis=1)
y = df['type']

# %%
print(x.shape, y.shape)

x = pd.get_dummies(x)
print(x.shape)
# Out:
# (8124, 22) (8124,)
# (8124, 117)

# %%
y = y.map({'edible':0, 'poisonous':1})

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: type, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=10, stratify=y)

print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (6499, 117) (1625, 117) (6499,) (1625,)

# %% [markdown]
# ## 모델 생성

# %%
model = MultinomialNB()
model.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# ## 모델 평가

# %%
model.classes_   # 모델이 분류해야할 클래스값 목록 보여줌
# Out:
# array([0, 1], dtype=int64)

# %%
y_hat = model.predict(x_test)
print('실제값:', np.array(y_test[:7]))
print('예측값:', y_hat[:7])
# Out:
# 실제값: [0 0 1 0 0 1 0]
# 예측값: [0 0 1 0 0 1 0]

# %%
cf_mat = confusion_matrix(y_test, y_hat)#, labels=['poisonous', 'edible'])  # labels: 네거티브와 포지티브에 사용할 분류값 지정
print(cf_mat)

print(f'정확도: {accuracy_score(y_test, y_hat):.3f}')
#print(f"정밀도: {precision_score(y_test, y_hat, pos_label='edible'):.3f}") # pos_label: 포지티브로 사용할 레이블 지정 필요
print(f"정밀도: {precision_score(y_test, y_hat):.3f}")
print(f'AUC: {roc_auc_score(y_test, model.predict_proba(x_test)[:,1]):.3f}')

# 순위형 명목형 데이터가 아니기때문에 원핫인코딩이 더 정확함
# Out:
# [[841   1]
#  [ 74 709]]
# 정확도: 0.954
# 정밀도: 0.999
# AUC: 0.997
